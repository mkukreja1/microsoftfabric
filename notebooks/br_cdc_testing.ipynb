# %% [markdown]
# #### Verify if the first iteration of the Bronze layer ingestion worked as desired.

# %%
# %%sql
# SELECT * FROM bronze_watermark_table;
#
# SELECT 'bronze_products_count', count(*) AS count FROM bronze_products
# UNION
# SELECT 'bronze_store_customers', count(*) AS count FROM bronze_store_customers
# UNION
# SELECT 'bronze_store_orders', count(*) AS count FROM bronze_store_orders
# UNION
# SELECT 'bronze_inventory', count(*) AS count FROM bronze_inventory

# %% [markdown]
# #### Verify if the second iteration of the Bronze layer ingestion worked as desired.

# %%
# %%sql
# SELECT * FROM bronze_watermark_table;
#
# SELECT 'bronze_products_count', count(*) AS count FROM bronze_products
# UNION
# SELECT 'bronze_store_customers', count(*) AS count FROM bronze_store_customers
# UNION
# SELECT 'bronze_store_orders', count(*) AS count FROM bronze_store_orders
# UNION
# SELECT 'bronze_inventory', count(*) AS count FROM bronze_inventory

# %% [markdown]
# #### Verify if the third iteration of the Bronze layer ingestion worked as desired.

# %%
# %%sql
# SELECT * FROM bronze_watermark_table;
#
# SELECT 'bronze_products_count', count(*) AS count FROM bronze_products
# UNION
# SELECT 'bronze_store_customers', count(*) AS count FROM bronze_store_customers
# UNION
# SELECT 'bronze_store_orders', count(*) AS count FROM bronze_store_orders
# UNION
# SELECT 'bronze_inventory', count(*) AS count FROM bronze_inventory

# %% [markdown]
# #### Verify if the fourth iteration of the Bronze layer ingestion worked as desired.

# %%
# %%sql
# SELECT * FROM bronze_watermark_table;
#
# SELECT 'bronze_products_count', count(*) AS count FROM bronze_products
# UNION
# SELECT 'bronze_store_customers', count(*) AS count FROM bronze_store_customers
# UNION
# SELECT 'bronze_store_orders', count(*) AS count FROM bronze_store_orders
# UNION
# SELECT 'bronze_inventory', count(*) AS count FROM bronze_inventory
