# %%
# %pip install azure-eventhub

# %%
order_list = [
{"customer_name": "Desirae Dale", "address": "P.O. Box 649, 1679 Sagittis Street", "city": "Annapolis County", "postalcode": "G9A 4V0", "country": "Canada", "phone": "1 (204) 967-4437", "email": "magnis.dis.parturient@loremipsumsodales.edu", "product_name": "Watch", "order_date": "23/04/2024", "currency": "CAD", "order_mode": "NEW", "sale_price":"549", "order_number":"854"},
{"customer_name": "Prescott Barnes", "address": "960-5386 Vel, Road", "city": "Pangnirtung", "postalcode": "L7H 5R3", "country": "Canada", "phone": "1 (204) 516-8169", "email": "Phasellus.vitae@vitae.co.uk", "product_name": "Vaccum", "order_date": "23/04/2024", "currency": "CAD", "order_mode": "NEW", "sale_price":"899.99", "order_number":"855"},
{"customer_name": "Zenaida Rowland", "address": "P.O. Box 344, 4750 Ultricies St.", "city": "Watson Lake", "postalcode": "P6M 3A7", "country": "Canada", "phone": "1 (579) 577-7471", "email": "Nulla.interdum.Curabitur@leo.com", "product_name": "Airconditioner", "order_date": "23/04/2024", "currency": "CAD", "order_mode": "NEW", "sale_price":"3398.99", "order_number":"856"},
{"customer_name": "Malcolm Pope", "address": "405-4625 Adipiscing Street", "city": "Montague", "postalcode": "H9S 6M8", "country": "Canada", "phone": "1 (902) 494-3034", "email": "nec@portaelit.co.uk", "product_name": "Microwave", "order_date": "23/04/2024", "currency": "CAD", "order_mode": "NEW", "sale_price":"55", "order_number":"857"},
{"customer_name": "Stephanie Dawson", "address": "P.O. Box 555, 5284 Ullamcorper, Road", "city": "Innisfail", "postalcode": "J8A 8B6", "country": "Canada", "phone": "1 (506) 414-0512", "email": "eleifend.nec@utlacus.com", "product_name": "DVD", "order_date": "23/04/2024", "currency": "CAD", "order_mode": "NEW", "sale_price":"27.99", "order_number":"858"},
{"customer_name": "Rogan Gardner", "address": "213-7831 Consectetuer Rd.", "city": "Arviat", "postalcode": "M8A 5J0", "country": "Canada", "phone": "1 (825) 477-5332", "email": "mi@ac.net", "product_name": "TV", "order_date": "23/04/2024", "currency": "CAD", "order_mode": "NEW", "sale_price":"229.99", "order_number":"859"},
{"customer_name": "Stone Francis", "address": "412-5819 Aliquam Rd.", "city": "Arviat", "postalcode": "S4L 4L4", "country": "Canada", "phone": "1 (306) 558-0184", "email": "Nullam@elitpharetraut.com", "product_name": "Keyboard", "order_date": "23/04/2024", "currency": "CAD", "order_mode": "NEW", "sale_price":"169.99", "order_number":"860"},
{"customer_name": "Galvin Cardenas", "address": "P.O. Box 210, 6725 Lorem, Street", "city": "Minitonas", "postalcode": "S0N 7N7", "country": "Canada", "phone": "1 (226) 134-9345", "email": "non@Nunclectuspede.org", "product_name": "Mice", "order_date": "23/04/2024", "currency": "CAD", "order_mode": "NEW", "sale_price":"9.99", "order_number":"861"},
{"customer_name": "Aphrodite Tyler", "address": "Ap #151-818 Elit Road", "city": "Qualicum Beach", "postalcode": "X4T 4H8", "country": "Canada", "phone": "1 (902) 474-3958", "email": "egestas@adipiscing.ca", "product_name": "Monitor", "order_date": "23/04/2024", "currency": "CAD", "order_mode": "NEW", "sale_price":"139.99", "order_number":"862"},
{"customer_name": "Cheryl Franklin", "address": "6688 Odio. Avenue", "city": "North Vancouver", "postalcode": "J6Z 1H6", "country": "Canada", "phone": "1 (587) 778-7378", "email": "eu.ultrices.sit@eros.ca", "product_name": "Mobile", "order_date": "23/04/2024", "currency": "CAD", "order_mode": "NEW", "sale_price":"399", "order_number":"863"},
{"customer_name": "Keith Parker", "address": "252-3959 Vivamus Rd.", "city": "Labrecque", "postalcode": "K6T 8X7", "country": "Canada", "phone": "1 (450) 310-3613", "email": "lacus.Quisque@aliquetProin.org", "product_name": "Airconditioner", "order_date": "23/04/2024", "currency": "CAD", "order_mode": "NEW", "sale_price":"43.77", "order_number":"864"},
{"customer_name": "Hannah Odom", "address": "Ap #564-8885 Proin Av.", "city": "Glovertown", "postalcode": "L2H 5B6", "country": "Canada", "phone": "1 (867) 653-7534", "email": "sem@amet.co.uk", "product_name": "DVD", "order_date": "23/04/2024", "currency": "CAD", "order_mode": "NEW", "sale_price":"47.65", "order_number":"865"},
{"customer_name": "Sacha Maynard", "address": "4634 Non, Rd.", "city": "Bearberry", "postalcode": "B9C 2E3", "country": "Canada", "phone": "1 (778) 622-1925", "email": "erat.vel@fermentumarcu.edu", "product_name": "Keyboard", "order_date": "23/04/2024", "currency": "CAD", "order_mode": "NEW", "sale_price":"32.1", "order_number":"866"},
{"customer_name": "Stephen Wilson", "address": "P.O. Box 608, 8057 Ut, Av.", "city": "Enterprise", "postalcode": "L8E 5G6", "country": "Canada", "phone": "1 (905) 629-9509", "email": "erat.eget@Inscelerisque.net", "product_name": "Mice", "order_date": "23/04/2024", "currency": "CAD", "order_mode": "NEW", "sale_price":"49.78", "order_number":"867"},
{"customer_name": "Quyn May", "address": "7206 Et Av.", "city": "Edmundston", "postalcode": "S8L 3N2", "country": "Canada", "phone": "1 (438) 219-0672", "email": "nec.ante.Maecenas@arcuimperdiet.com", "product_name": "Microwave", "order_date": "23/04/2024", "currency": "CAD", "order_mode": "NEW", "sale_price":"64.4", "order_number":"868"},
{"customer_name": "Quintessa Parsons", "address": "3617 Integer Av.", "city": "Gravelbourg", "postalcode": "J5E 3A3", "country": "Canada", "phone": "1 (778) 602-1908", "email": "ipsum.primis@mauris.com", "product_name": "Mobile", "order_date": "23/04/2024", "currency": "CAD", "order_mode": "NEW", "sale_price":"43.77", "order_number":"869"},
{"customer_name": "Omar Mcdaniel", "address": "6217 Tellus. Rd.", "city": "Woodstock", "postalcode": "C4B 8T8", "country": "Canada", "phone": "1 (365) 881-1198", "email": "nulla@pede.com", "product_name": "Monitor", "order_date": "23/04/2024", "currency": "CAD", "order_mode": "NEW", "sale_price":"25.6", "order_number":"870"},
{"customer_name": "Neville Richards", "address": "247-6301 Fringilla Av.", "city": "Fredericton", "postalcode": "X4E 6W9", "country": "Canada", "phone": "1 (902) 906-1946", "email": "facilisis@Suspendissealiquet.com", "product_name": "Vaccum", "order_date": "23/04/2024", "currency": "CAD", "order_mode": "NEW", "sale_price":"22.35", "order_number":"871"},
{"customer_name": "Keely Reilly", "address": "Ap #761-1000 In Av.", "city": "Whitehorse", "postalcode": "V7N 0V0", "country": "Canada", "phone": "1 (289) 288-7364", "email": "faucibus.orci.luctus@urnaNuncquis.com", "product_name": "Watch", "order_date": "23/04/2024", "currency": "CAD", "order_mode": "NEW", "sale_price":"10.4", "order_number":"872"},
{"customer_name": "Wynne Rogers", "address": "4008 Lectus St.", "city": "Prince Albert", "postalcode": "N2B 2X3", "country": "Canada", "phone": "1 (250) 911-5387", "email": "sollicitudin.orci@Nullaeuneque.com", "product_name": "Watch", "order_date": "23/04/2024", "currency": "CAD", "order_mode": "NEW", "sale_price":"54.45", "order_number":"873"},
{"customer_name": "Astra Wolfe", "address": "685-6633 Imperdiet Av.", "city": "Salt Spring Island", "postalcode": "S7C 9W6", "country": "Canada", "phone": "1 (236) 751-8114", "email": "purus.Nullam@Maecenasornare.co.uk", "product_name": "Vaccum", "order_date": "23/04/2024", "currency": "CAD", "order_mode": "NEW", "sale_price":"242.34", "order_number":"874"},
{"customer_name": "Neve Middleton", "address": "613-2382 Nullam Av.", "city": "Gespeg", "postalcode": "N8K 1R8", "country": "Canada", "phone": "1 (873) 724-2894", "email": "cubilia@ridiculus.net", "product_name": "Airconditioner", "order_date": "23/04/2024", "currency": "CAD", "order_mode": "NEW", "sale_price":"549", "order_number":"875"},
{"customer_name": "Meghan Shepard", "address": "4807 Erat Rd.", "city": "Belcarra", "postalcode": "C4K 7H9", "country": "Canada", "phone": "1 (506) 333-1353", "email": "condimentum@aliquetmolestie.ca", "product_name": "Microwave", "order_date": "23/04/2024", "currency": "CAD", "order_mode": "NEW", "sale_price":"899.99", "order_number":"876"},
{"customer_name": "Remedios Kline", "address": "P.O. Box 658, 5723 Pede Street", "city": "Rimbey", "postalcode": "R4A 3B1", "country": "Canada", "phone": "1 (587) 590-6469", "email": "lobortis.ultrices@eusem.org", "product_name": "DVD", "order_date": "23/04/2024", "currency": "CAD", "order_mode": "NEW", "sale_price":"3398.99", "order_number":"877"},
{"customer_name": "Emery Swanson", "address": "5487 Non, St.", "city": "Gander", "postalcode": "M5L 2G1", "country": "Canada", "phone": "1 (782) 908-6338", "email": "justo@sitametmetus.net", "product_name": "TV", "order_date": "23/04/2024", "currency": "CAD", "order_mode": "NEW", "sale_price":"55", "order_number":"878"},
{"customer_name": "Deepamala Patel", "address": "P.O. Box 365, 7013 Ut Street", "city": "Kavaratti", "postalcode": "802156", "country": "India", "phone": "+91 0276449963", "email": "turpis.In@in.net", "product_name": "Keyboard", "order_date": "23/04/2024", "currency": "INR", "order_mode": "NEW", "sale_price":"27.99", "order_number":"879"},
{"customer_name": "Neelesh Jain", "address": "P.O. Box 149, 787 Aenean Street", "city": "Silvassa", "postalcode": "704134", "country": "India", "phone": "+91 9820194275", "email": "magna@sociisnatoquepenatibus.co.uk", "product_name": "Mice", "order_date": "23/04/2024", "currency": "INR", "order_mode": "NEW", "sale_price":"229.99", "order_number":"880"},
{"customer_name": "Nilima Singh", "address": "P.O. Box 214, 4463 In, Av.", "city": "Imphal", "postalcode": "954348", "country": "India", "phone": "+91 4373534861", "email": "commodo@nonummy.com", "product_name": "Monitor", "order_date": "23/04/2024", "currency": "INR", "order_mode": "NEW", "sale_price":"169.99", "order_number":"881"},
{"customer_name": "Pratima Ismail", "address": "P.O. Box 382, 8517 Semper Street", "city": "Haridwar", "postalcode": "676726", "country": "India", "phone": "+91 4201530979", "email": "torquent@fringillapurus.ca", "product_name": "Mobile", "order_date": "23/04/2024", "currency": "INR", "order_mode": "NEW", "sale_price":"9.99", "order_number":"882"},
{"customer_name": "Shorashi Ismail", "address": "2749 Purus St.", "city": "Aizwal", "postalcode": "393596", "country": "India", "phone": "+91 8644190153", "email": "ac.metus@fermentummetus.com", "product_name": "Keyboard", "order_date": "23/04/2024", "currency": "INR", "order_mode": "NEW", "sale_price":"139.99", "order_number":"883"},
{"customer_name": "Ilavenil Khan", "address": "407-2935 Quisque Road", "city": "Itanagar", "postalcode": "112605", "country": "India", "phone": "+91 3517700987", "email": "mauris.sit.amet@Aliquamrutrumlorem.net", "product_name": "Mice", "order_date": "23/04/2024", "currency": "INR", "order_mode": "NEW", "sale_price":"399", "order_number":"884"},
{"customer_name": "Parakram Ismail", "address": "Ap #630-4998 Purus St.", "city": "Chiniot", "postalcode": "278425", "country": "India", "phone": "+91 3891556950", "email": "eu.eros@necleo.org", "product_name": "Microwave", "order_date": "23/04/2024", "currency": "INR", "order_mode": "NEW", "sale_price":"43.77", "order_number":"885"},
{"customer_name": "Roshan Ismail", "address": "Ap #622-6212 Ligula. Ave", "city": "Srinagar", "postalcode": "741209", "country": "India", "phone": "+91 2405203355", "email": "massa@duinec.net", "product_name": "Mobile", "order_date": "23/04/2024", "currency": "INR", "order_mode": "NEW", "sale_price":"47.65", "order_number":"886"},
{"customer_name": "Balbir Jain", "address": "P.O. Box 737, 6103 Donec Rd.", "city": "Durgapur", "postalcode": "384320", "country": "India", "phone": "+91 4496045205", "email": "facilisis.lorem@malesuada.org", "product_name": "Monitor", "order_date": "23/04/2024", "currency": "INR", "order_mode": "NEW", "sale_price":"32.1", "order_number":"887"},
{"customer_name": "Devamati Kumar", "address": "P.O. Box 391, 5439 At, Rd.", "city": "Itanagar", "postalcode": "279504", "country": "India", "phone": "+91 6749874705", "email": "auctor.vitae@Quisquelibero.org", "product_name": "Vaccum", "order_date": "23/04/2024", "currency": "INR", "order_mode": "NEW", "sale_price":"49.78", "order_number":"888"},
{"customer_name": "Heera Patel", "address": "P.O. Box 814, 247 Quisque St.", "city": "Daman", "postalcode": "921978", "country": "India", "phone": "+91 2208071682", "email": "posuere@tortor.co.uk", "product_name": "Watch", "order_date": "23/04/2024", "currency": "INR", "order_mode": "NEW", "sale_price":"64.4", "order_number":"889"},
{"customer_name": "Amartya Singh", "address": "Ap #976-8679 Habitant Ave", "city": "Silvassa", "postalcode": "916257", "country": "India", "phone": "+91 1828577322", "email": "In.tincidunt.congue@semNullainterdum.co.uk", "product_name": "Watch", "order_date": "23/04/2024", "currency": "INR", "order_mode": "NEW", "sale_price":"43.77", "order_number":"890"},
{"customer_name": "Shubha Patel", "address": "Ap #837-3609 A, Rd.", "city": "Bijapur", "postalcode": "766394", "country": "India", "phone": "+91 5645551624", "email": "tempor@nisi.edu", "product_name": "Vaccum", "order_date": "23/04/2024", "currency": "INR", "order_mode": "NEW", "sale_price":"25.6", "order_number":"891"},
{"customer_name": "Suvarnmala Raj", "address": "Ap #851-3632 Pellentesque Rd.", "city": "Agartala", "postalcode": "533118", "country": "India", "phone": "+91 8256015722", "email": "Nulla.tincidunt@vulputate.org", "product_name": "Airconditioner", "order_date": "23/04/2024", "currency": "INR", "order_mode": "NEW", "sale_price":"22.35", "order_number":"892"},
{"customer_name": "Sambhav Ismail", "address": "P.O. Box 531, 2053 Ut Street", "city": "Kota", "postalcode": "904617", "country": "India", "phone": "+91 0023886107", "email": "cursus@eutellus.co.uk", "product_name": "Microwave", "order_date": "23/04/2024", "currency": "INR", "order_mode": "NEW", "sale_price":"10.4", "order_number":"893"},
{"customer_name": "Gautami Patel", "address": "9793 Molestie Ave", "city": "Cuttack", "postalcode": "720149", "country": "India", "phone": "+91 9947319544", "email": "mus.Proin@neque.ca", "product_name": "DVD", "order_date": "23/04/2024", "currency": "INR", "order_mode": "NEW", "sale_price":"54.45", "order_number":"894"},
{"customer_name": "Aravan Ismail", "address": "660-6873 Ut Av.", "city": "Srinagar", "postalcode": "376519", "country": "India", "phone": "+91 5828883518", "email": "ornare.libero.at@feugiatLoremipsum.net", "product_name": "Vaccum", "order_date": "23/04/2024", "currency": "INR", "order_mode": "NEW", "sale_price":"242.34", "order_number":"895"},
{"customer_name": "Atmaja Jain", "address": "3146 Amet Rd.", "city": "Bhilai", "postalcode": "278051", "country": "India", "phone": "+91 0997272347", "email": "eleifend@vestibulum.com", "product_name": "Airconditioner", "order_date": "23/04/2024", "currency": "INR", "order_mode": "NEW", "sale_price":"43.77", "order_number":"896"},
{"customer_name": "Sameena Kumar", "address": "Ap #591-5228 Proin St.", "city": "Nagaon", "postalcode": "190166", "country": "India", "phone": "+91 5852706132", "email": "Quisque@cursusInteger.edu", "product_name": "Microwave", "order_date": "23/04/2024", "currency": "INR", "order_mode": "NEW", "sale_price":"47.65", "order_number":"897"},
{"customer_name": "Sengannan Patel", "address": "536-4201 Massa. St.", "city": "Brahmapur", "postalcode": "121099", "country": "India", "phone": "+91 2189595662", "email": "id.risus@Pellentesque.org", "product_name": "DVD", "order_date": "23/04/2024", "currency": "INR", "order_mode": "NEW", "sale_price":"32.1", "order_number":"898"},
{"customer_name": "Shakeel Raj", "address": "P.O. Box 175, 6114 Consequat, Road", "city": "Sikar", "postalcode": "337884", "country": "India", "phone": "+91 5897857431", "email": "ut.odio@anteVivamus.org", "product_name": "TV", "order_date": "23/04/2024", "currency": "INR", "order_mode": "NEW", "sale_price":"49.78", "order_number":"899"},
{"customer_name": "Parijat Ismail", "address": "Ap #881-5836 Erat. Rd.", "city": "Dehradun", "postalcode": "639062", "country": "India", "phone": "+91 7887275535", "email": "pellentesque@duiaugueeu.org", "product_name": "Keyboard", "order_date": "23/04/2024", "currency": "INR", "order_mode": "NEW", "sale_price":"64.4", "order_number":"900"},
{"customer_name": "Rukmini Patel", "address": "P.O. Box 264, 3707 Interdum Ave", "city": "Kavaratti", "postalcode": "270372", "country": "India", "phone": "+91 4921681240", "email": "Aliquam.ornare.libero@maurisut.edu", "product_name": "Mice", "order_date": "23/04/2024", "currency": "INR", "order_mode": "NEW", "sale_price":"43.77", "order_number":"901"},
{"customer_name": "Rathin Khan", "address": "312-8665 In Avenue", "city": "Durg", "postalcode": "898504", "country": "India", "phone": "+91 6694322111", "email": "feugiat.metus.sit@nascetur.co.uk", "product_name": "Monitor", "order_date": "23/04/2024", "currency": "INR", "order_mode": "NEW", "sale_price":"25.6", "order_number":"902"},
{"customer_name": "Niharika Patel", "address": "7409 Nec Avenue", "city": "Porbandar", "postalcode": "897623", "country": "India", "phone": "+91 3100692106", "email": "turpis.Nulla@ipsum.org", "product_name": "Mobile", "order_date": "23/04/2024", "currency": "INR", "order_mode": "NEW", "sale_price":"22.35", "order_number":"903"},
{"customer_name": "Jacob Bauer", "address": "835-236 Eros Ave", "city": "Montrose", "postalcode": "O9 3YU", "country": "United Kingdom", "phone": "05746 744686", "email": "in.cursus.et@nislarcu.org", "product_name": "Keyboard", "order_date": "23/04/2024", "currency": "EUR", "order_mode": "NEW", "sale_price":"10.4", "order_number":"904"},
{"customer_name": "Kirsten Fry", "address": "1124 Nulla. Ave", "city": "Menai Bridge", "postalcode": "C3 9OD", "country": "United Kingdom", "phone": "04572 600457", "email": "a.nunc@ultricesaauctor.net", "product_name": "Mice", "order_date": "23/04/2024", "currency": "EUR", "order_mode": "NEW", "sale_price":"54.45", "order_number":"905"},
{"customer_name": "Stella Tillman", "address": "P.O. Box 226, 3850 Dolor. St.", "city": "Wick", "postalcode": "U0A 4SP", "country": "United Kingdom", "phone": "07583 844423", "email": "eu.dui@massa.com", "product_name": "Microwave", "order_date": "23/04/2024", "currency": "EUR", "order_mode": "NEW", "sale_price":"242.34", "order_number":"906"},
{"customer_name": "Mariko Robles", "address": "7595 Arcu. Av.", "city": "Ammanford", "postalcode": "YD95 4MU", "country": "United Kingdom", "phone": "04569 656348", "email": "Pellentesque.ultricies@auctor.com", "product_name": "Watch", "order_date": "23/04/2024", "currency": "EUR", "order_mode": "NEW", "sale_price":"549", "order_number":"907"},
{"customer_name": "Athena Rose", "address": "5582 Molestie Ave", "city": "Crewe", "postalcode": "C56 3CH", "country": "United Kingdom", "phone": "02346 022479", "email": "lorem@idmagnaet.org", "product_name": "Vaccum", "order_date": "23/04/2024", "currency": "EUR", "order_mode": "NEW", "sale_price":"242.34", "order_number":"908"},
{"customer_name": "Sacha Browning", "address": "8746 Ante. Ave", "city": "Llandovery", "postalcode": "HH20 4GT", "country": "United Kingdom", "phone": "08606 357081", "email": "in.cursus@metusurnaconvallis.edu", "product_name": "Airconditioner", "order_date": "23/04/2024", "currency": "EUR", "order_mode": "NEW", "sale_price":"899.99", "order_number":"909"},
{"customer_name": "Jasmine Welch", "address": "P.O. Box 127, 9506 Molestie Street", "city": "Kington", "postalcode": "N7T 2UU", "country": "United Kingdom", "phone": "06377 937072", "email": "senectus.et@urnasuscipitnonummy.co.uk", "product_name": "Microwave", "order_date": "23/04/2024", "currency": "EUR", "order_mode": "NEW", "sale_price":"3398.99", "order_number":"910"},
{"customer_name": "Stella Gallagher", "address": "Ap #704-112 Erat Avenue", "city": "Tullibody", "postalcode": "TA30 4IW", "country": "United Kingdom", "phone": "00059 757286", "email": "dapibus.quam.quis@amet.co.uk", "product_name": "DVD", "order_date": "23/04/2024", "currency": "EUR", "order_mode": "NEW", "sale_price":"55", "order_number":"911"},
{"customer_name": "Aubrey Norris", "address": "Ap #943-1347 Imperdiet Avenue", "city": "Coldstream", "postalcode": "D10 5JV", "country": "United Kingdom", "phone": "07672 321093", "email": "sollicitudin@enimmitempor.ca", "product_name": "TV", "order_date": "23/04/2024", "currency": "EUR", "order_mode": "NEW", "sale_price":"27.99", "order_number":"912"},
{"customer_name": "Jemima Trujillo", "address": "654 Proin Rd.", "city": "Ipswich", "postalcode": "KR5 7PK", "country": "United Kingdom", "phone": "01006 612034", "email": "commodo.tincidunt.nibh@montesnascetur.ca", "product_name": "Keyboard", "order_date": "23/04/2024", "currency": "EUR", "order_mode": "NEW", "sale_price":"229.99", "order_number":"913"},
{"customer_name": "Imogene Baxter", "address": "126-4688 Cras Ave", "city": "Morpeth", "postalcode": "E69 2XQ", "country": "United Kingdom", "phone": "00992 334267", "email": "lorem@Inat.edu", "product_name": "Mice", "order_date": "23/04/2024", "currency": "EUR", "order_mode": "NEW", "sale_price":"169.99", "order_number":"914"},
{"customer_name": "Cameron Klein", "address": "Ap #270-9828 Eleifend, Rd.", "city": "West Ham", "postalcode": "OT7S 4SF", "country": "United Kingdom", "phone": "05506 255298", "email": "ornare@sedorcilobortis.edu", "product_name": "Monitor", "order_date": "23/04/2024", "currency": "EUR", "order_mode": "NEW", "sale_price":"9.99", "order_number":"915"},
{"customer_name": "August Reid", "address": "2287 Est. Road", "city": "Monmouth", "postalcode": "VS22 0QP", "country": "United Kingdom", "phone": "00105 564763", "email": "dui.nec.urna@tellussemmollis.edu", "product_name": "Mobile", "order_date": "23/04/2024", "currency": "EUR", "order_mode": "NEW", "sale_price":"139.99", "order_number":"916"},
{"customer_name": "Demetria Dickson", "address": "P.O. Box 488, 4619 Ante Av.", "city": "Auldearn", "postalcode": "GC95 1WV", "country": "United Kingdom", "phone": "06484 118410", "email": "lorem@bibendumfermentummetus.com", "product_name": "Airconditioner", "order_date": "23/04/2024", "currency": "EUR", "order_mode": "NEW", "sale_price":"399", "order_number":"917"},
{"customer_name": "Emerson Emerson", "address": "285-8894 Vel Av.", "city": "Lutterworth", "postalcode": "G30 7QJ", "country": "United Kingdom", "phone": "05396 403830", "email": "tristique.ac@ipsumSuspendissenon.edu", "product_name": "DVD", "order_date": "23/04/2024", "currency": "EUR", "order_mode": "NEW", "sale_price":"43.77", "order_number":"918"},
{"customer_name": "Ursa Reyes", "address": "P.O. Box 816, 6210 Ipsum St.", "city": "Rothes", "postalcode": "BO59 9FT", "country": "United Kingdom", "phone": "01344 141765", "email": "natoque@commodohendreritDonec.org", "product_name": "Keyboard", "order_date": "23/04/2024", "currency": "EUR", "order_mode": "NEW", "sale_price":"47.65", "order_number":"919"},
{"customer_name": "Merritt Schroeder", "address": "764-8016 Nulla Avenue", "city": "Banff", "postalcode": "PU32 5EV", "country": "United Kingdom", "phone": "02723 981427", "email": "at@turpisnec.ca", "product_name": "Mice", "order_date": "23/04/2024", "currency": "EUR", "order_mode": "NEW", "sale_price":"32.1", "order_number":"920"},
{"customer_name": "Steel Fulton", "address": "977-9631 Erat Av.", "city": "Oswestry", "postalcode": "W8L 5OO", "country": "United Kingdom", "phone": "07148 882859", "email": "nec@consequatauctornunc.net", "product_name": "Microwave", "order_date": "23/04/2024", "currency": "EUR", "order_mode": "NEW", "sale_price":"49.78", "order_number":"921"},
{"customer_name": "Steel Beasley", "address": "526 A, Road", "city": "Dunbar", "postalcode": "L8U 3CV", "country": "United Kingdom", "phone": "06725 223045", "email": "sit.amet.consectetuer@est.com", "product_name": "Mobile", "order_date": "23/04/2024", "currency": "EUR", "order_mode": "NEW", "sale_price":"64.4", "order_number":"922"},
{"customer_name": "Joan Lynn", "address": "7308 Ligula Avenue", "city": "Henley-on-Thames", "postalcode": "W8 5BY", "country": "United Kingdom", "phone": "00522 079684", "email": "lacus.Etiam.bibendum@etarcuimperdiet.net", "product_name": "Monitor", "order_date": "23/04/2024", "currency": "EUR", "order_mode": "NEW", "sale_price":"43.77", "order_number":"923"},
{"customer_name": "Jordan Lynn", "address": "4423 Proin Street", "city": "Clackmannan", "postalcode": "HI56 8MH", "country": "United Kingdom", "phone": "03705 060162", "email": "eget.metus@rutrumurnanec.net", "product_name": "Vaccum", "order_date": "23/04/2024", "currency": "EUR", "order_mode": "NEW", "sale_price":"25.6", "order_number":"924"},
{"customer_name": "Bruno Hebert", "address": "8566 Nisi Avenue", "city": "Llangollen", "postalcode": "CE2 4WW", "country": "United Kingdom", "phone": "02794 010514", "email": "Donec.non@dapibusrutrum.com", "product_name": "Watch", "order_date": "23/04/2024", "currency": "EUR", "order_mode": "NEW", "sale_price":"22.35", "order_number":"925"},
{"customer_name": "Guy Bartlett", "address": "699-5960 Risus. Avenue", "city": "Carmarthen", "postalcode": "XJ6M 6WQ", "country": "United Kingdom", "phone": "04417 162161", "email": "non.egestas.a@semelit.org", "product_name": "Watch", "order_date": "23/04/2024", "currency": "EUR", "order_mode": "NEW", "sale_price":"10.4", "order_number":"926"},
{"customer_name": "Blythe Hickman", "address": "P.O. Box 913, 5022 Proin Street", "city": "Forfar", "postalcode": "E2N 5JH", "country": "United Kingdom", "phone": "00747 611821", "email": "Cras.lorem@quispedePraesent.com", "product_name": "Vaccum", "order_date": "23/04/2024", "currency": "EUR", "order_mode": "NEW", "sale_price":"54.45", "order_number":"927"},
{"customer_name": "Gretchen Mills", "address": "3483 Mus. Rd.", "city": "Wigtown", "postalcode": "Z2 4DD", "country": "United Kingdom", "phone": "05498 328756", "email": "sem@eunequepellentesque.com", "product_name": "Airconditioner", "order_date": "23/04/2024", "currency": "EUR", "order_mode": "NEW", "sale_price":"242.34", "order_number":"928"},
{"customer_name": "Cameron Barnett", "address": "Ap #876-8845 Ipsum Street", "city": "Lansing", "postalcode": "39681", "country": "United States", "phone": "1-257-619-1306", "email": "facilisis@nonmassanon.net", "product_name": "Microwave", "order_date": "23/04/2024", "currency": "USD", "order_mode": "NEW", "sale_price":"549", "order_number":"929"},
{"customer_name": "Freya Phelps", "address": "Ap #846-4780 Lorem, Avenue", "city": "Bridgeport", "postalcode": "14813", "country": "United States", "phone": "1-565-982-2870", "email": "Pellentesque@velitCras.edu", "product_name": "DVD", "order_date": "23/04/2024", "currency": "USD", "order_mode": "NEW", "sale_price":"64.4", "order_number":"930"},
{"customer_name": "Kibo Sharp", "address": "Ap #800-5242 Neque Rd.", "city": "Sacramento", "postalcode": "60537", "country": "United States", "phone": "1-136-713-9111", "email": "neque.sed.sem@fringilla.edu", "product_name": "TV", "order_date": "23/04/2024", "currency": "USD", "order_mode": "NEW", "sale_price":"43.77", "order_number":"931"},
{"customer_name": "Zelda Daniel", "address": "7422 Quis, Av.", "city": "Springfield", "postalcode": "35016", "country": "United States", "phone": "1-629-589-6553", "email": "rutrum.non@Aliquamornare.com", "product_name": "Keyboard", "order_date": "23/04/2024", "currency": "USD", "order_mode": "NEW", "sale_price":"25.6", "order_number":"932"},
{"customer_name": "Glenna Rowe", "address": "8192 Magna. Avenue", "city": "Grand Rapids", "postalcode": "81752", "country": "United States", "phone": "1-989-747-9256", "email": "ullamcorper.nisl.arcu@non.net", "product_name": "Mice", "order_date": "23/04/2024", "currency": "USD", "order_mode": "NEW", "sale_price":"22.35", "order_number":"933"},
{"customer_name": "Jackson Fletcher", "address": "6466 Semper Street", "city": "Toledo", "postalcode": "38914", "country": "United States", "phone": "1-513-717-7252", "email": "Fusce@In.co.uk", "product_name": "Monitor", "order_date": "23/04/2024", "currency": "USD", "order_mode": "NEW", "sale_price":"10.4", "order_number":"934"},
{"customer_name": "Hasad Tran", "address": "6321 Interdum Street", "city": "Metairie", "postalcode": "92959", "country": "United States", "phone": "1-302-532-3833", "email": "cubilia.Curae.Donec@orcilacusvestibulum.net", "product_name": "Mobile", "order_date": "23/04/2024", "currency": "USD", "order_mode": "NEW", "sale_price":"54.45", "order_number":"935"},
{"customer_name": "Justin Kramer", "address": "436 Proin Road", "city": "Gary", "postalcode": "89099", "country": "United States", "phone": "1-163-808-7095", "email": "ipsum.sodales@Suspendisseseddolor.edu", "product_name": "Keyboard", "order_date": "23/04/2024", "currency": "USD", "order_mode": "NEW", "sale_price":"242.34", "order_number":"936"},
{"customer_name": "Tyrone Nichols", "address": "Ap #875-378 Nulla Ave", "city": "Lawton", "postalcode": "88229", "country": "United States", "phone": "1-959-463-6741", "email": "magnis.dis.parturient@vel.net", "product_name": "Mice", "order_date": "23/04/2024", "currency": "USD", "order_mode": "NEW", "sale_price":"549", "order_number":"937"},
{"customer_name": "Quin Shepard", "address": "P.O. Box 879, 5653 Odio, St.", "city": "Springdale", "postalcode": "21678", "country": "United States", "phone": "1-843-880-7379", "email": "et@a.net", "product_name": "Microwave", "order_date": "23/04/2024", "currency": "USD", "order_mode": "NEW", "sale_price":"399", "order_number":"938"},
{"customer_name": "Phillip Hernandez", "address": "123-3155 Sit Avenue", "city": "Vancouver", "postalcode": "95246", "country": "United States", "phone": "1-955-895-4868", "email": "natoque.penatibus.et@aceleifendvitae.co.uk", "product_name": "Mobile", "order_date": "23/04/2024", "currency": "USD", "order_mode": "NEW", "sale_price":"43.77", "order_number":"939"},
{"customer_name": "Sage Gilmore", "address": "3078 Lobortis Rd.", "city": "Gary", "postalcode": "60390", "country": "United States", "phone": "1-870-973-2794", "email": "consectetuer@imperdietullamcorperDuis.org", "product_name": "Monitor", "order_date": "23/04/2024", "currency": "USD", "order_mode": "NEW", "sale_price":"47.65", "order_number":"940"},
{"customer_name": "Serina Salazar", "address": "P.O. Box 791, 8713 Facilisi. Rd.", "city": "New Orleans", "postalcode": "69230", "country": "United States", "phone": "1-318-598-4983", "email": "blandit@ultriciesadipiscing.com", "product_name": "Vaccum", "order_date": "23/04/2024", "currency": "USD", "order_mode": "NEW", "sale_price":"32.1", "order_number":"941"},
{"customer_name": "Darrel Stephens", "address": "Ap #762-3575 Consectetuer, Av.", "city": "Aurora", "postalcode": "42552", "country": "United States", "phone": "1-320-467-2664", "email": "nec@egestasAliquam.edu", "product_name": "Watch", "order_date": "23/04/2024", "currency": "USD", "order_mode": "NEW", "sale_price":"49.78", "order_number":"942"},
{"customer_name": "Bertha Estes", "address": "P.O. Box 859, 865 Ipsum Avenue", "city": "Memphis", "postalcode": "39185", "country": "United States", "phone": "1-633-294-6116", "email": "molestie.pharetra@lobortisquam.co.uk", "product_name": "Watch", "order_date": "23/04/2024", "currency": "USD", "order_mode": "NEW", "sale_price":"64.4", "order_number":"943"},
{"customer_name": "Elizabeth Barrett", "address": "220-5004 Dui, Ave", "city": "Fayetteville", "postalcode": "15349", "country": "United States", "phone": "1-343-285-8216", "email": "neque.tellus@tristique.co.uk", "product_name": "Vaccum", "order_date": "23/04/2024", "currency": "USD", "order_mode": "NEW", "sale_price":"43.77", "order_number":"944"},
{"customer_name": "Ira Lucas", "address": "936-3011 Convallis Road", "city": "Shreveport", "postalcode": "67365", "country": "United States", "phone": "1-117-676-2784", "email": "nec@lectus.net", "product_name": "Airconditioner", "order_date": "23/04/2024", "currency": "USD", "order_mode": "NEW", "sale_price":"25.6", "order_number":"945"},
{"customer_name": "Quinn Baird", "address": "931-6406 Etiam Rd.", "city": "Lawton", "postalcode": "82008", "country": "United States", "phone": "1-841-548-1457", "email": "egestas.lacinia@elitelitfermentum.co.uk", "product_name": "Microwave", "order_date": "23/04/2024", "currency": "USD", "order_mode": "NEW", "sale_price":"22.35", "order_number":"946"},
{"customer_name": "Alice Oconnor", "address": "8079 Sollicitudin Avenue", "city": "Mobile", "postalcode": "80841", "country": "United States", "phone": "1-819-757-3779", "email": "gravida@odioauctor.ca", "product_name": "DVD", "order_date": "23/04/2024", "currency": "USD", "order_mode": "NEW", "sale_price":"10.4", "order_number":"947"},
{"customer_name": "Zelenia Marks", "address": "700-4461 Quam, Rd.", "city": "Aurora", "postalcode": "63784", "country": "United States", "phone": "1-557-755-7348", "email": "interdum.ligula@porttitorerosnec.edu", "product_name": "Vaccum", "order_date": "23/04/2024", "currency": "USD", "order_mode": "NEW", "sale_price":"54.45", "order_number":"948"},
{"customer_name": "Amela Pierce", "address": "P.O. Box 673, 5111 Sagittis St.", "city": "Kaneohe", "postalcode": "50874", "country": "United States", "phone": "1-505-889-3221", "email": "Quisque.imperdiet.erat@orci.co.uk", "product_name": "Airconditioner", "order_date": "23/04/2024", "currency": "USD", "order_mode": "NEW", "sale_price":"242.34", "order_number":"949"},
{"customer_name": "Haviva Pollard", "address": "P.O. Box 900, 909 At Ave", "city": "Reno", "postalcode": "10231", "country": "United States", "phone": "1-677-355-8148", "email": "a@ridiculusmus.ca", "product_name": "Microwave", "order_date": "23/04/2024", "currency": "USD", "order_mode": "NEW", "sale_price":"43.77", "order_number":"950"},
{"customer_name": "Gannon Lee", "address": "P.O. Box 691, 8683 Magna. Road", "city": "Wyoming", "postalcode": "28661", "country": "United States", "phone": "1-548-107-2899", "email": "vitae.dolor.Donec@Nullamvitae.org", "product_name": "DVD", "order_date": "23/04/2024", "currency": "USD", "order_mode": "NEW", "sale_price":"47.65", "order_number":"951"},
{"customer_name": "Vivien Morin", "address": "P.O. Box 540, 3448 Tortor St.", "city": "Columbus", "postalcode": "40902", "country": "United States", "phone": "1-646-471-9748", "email": "Vivamus.sit.amet@ipsumCurabiturconsequat.edu", "product_name": "TV", "order_date": "23/04/2024", "currency": "USD", "order_mode": "NEW", "sale_price":"32.1", "order_number":"952"},
{"customer_name": "Rafael Chandler", "address": "787-2927 Sagittis Rd.", "city": "West Jordan", "postalcode": "26496", "country": "United States", "phone": "1-847-273-5005", "email": "fringilla.mi@ametmassaQuisque.net", "product_name": "Keyboard", "order_date": "23/04/2024", "currency": "USD", "order_mode": "NEW", "sale_price":"49.78", "order_number":"953"}
]

# %%
from azure.eventhub import EventHubProducerClient, EventData
import json
import time

#Replace values below
eventhub_connection_string = ''

eh_producer = EventHubProducerClient.from_connection_string(eventhub_connection_string)

# %%
try:
    for order in order_list:
        event_data = EventData(json.dumps(order).encode('utf-8'))
        eh_producer.send_event(event_data)
        time.sleep(1)
        print(event_data)
    eh_producer.flush()
    print("Message produced!")
except Exception as e:
    print(f"Error producing message: {e}")
finally:
    eh_producer.close()
